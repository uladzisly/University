# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/tasks2/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B59.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Введите день')
i = int(input())
h = i//60
mi = i-60*h
if mi<11:print(f'{h}:0{mi}')
else:print(f'{h}:{mi}')
# Out:
# Введите день
# 125
# 2:05
