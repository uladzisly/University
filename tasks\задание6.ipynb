# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/tasks%5C%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Введите секунды')
n = int(input())
print(f'{n//3600} {n//60}')
# Out:
# Введите секунды
# 3000
# 0 50
