# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/tasks/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B54.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Напишите число')
s = int(input())
print(f'слудующее число:{s+1}')
print(f'предыдущее число число:{s-1}')
# Out:
# Напишите число
# 150
# слудующее число:151
# предыдущее число число:149
