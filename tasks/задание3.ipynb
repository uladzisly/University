# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/tasks/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Как вас зовут?')
s = input()
print('Привет, '+s+'!')
# Out:
# Как вас зовут?
# g
# Привет, g!
