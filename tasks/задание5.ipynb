# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/tasks/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Число студентов')
st = int(input())
print('Число яблок')
ya = int(input())
print(f'Яблок у студентов:{ya//st}, в карзине:{ya%st}')
# Out:
# Число студентов
# 6
# Число яблок
# 50
# Яблок у студентов:8, в карзине:2
