# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Введите первое число')
m = []
m.append(int(input()))
print('Введите второе число')
m.append(int(input()))
print('Введите третье число')
m.append(int(input()))
print(sum(m))
# Out:
# Введите первое число
# 1
# Введите второе число
# 2
# Введите третье число
# 3
# 6
