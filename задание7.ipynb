# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B57.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Введите час первой точки')
h1 = int(input())*3600
print('Введите минуту первой точки')
m1 = int(input())*60
print('Введите секунду первой точки')
s1 = int(input())
p1 = h1+m1+s1
print('Введите час второй точки')
h2 = int(input())*3600
print('Введите минуту второй точки')
m2 = int(input())*60
print('Введите секунду второй точки')
s2 = int(input())
p2 = h2+m2+s2
print(p2-p1)
# Out:
# Введите час первой точки
# 1
# Введите минуту первой точки
# 2
# Введите секунду первой точки
# 30
# Введите час второй точки
# 1
# Введите минуту второй точки
# 3
# Введите секунду второй точки
# 20
# 50
