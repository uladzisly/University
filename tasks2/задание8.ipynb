# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/tasks2/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B58.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Введите день')
i = int(input())
if i%7==0:
  print(3)
if i%7==1:
  print(4)
if i%7==2:
  print(5)
if i%7==3:
  print(6)
if i%7==4:
  print(0)
if i%7==5:
  print(1)
if i%7==6:
  print(2)
# Out:
# Введите день
# 14
# 3
