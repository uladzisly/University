# %% [markdown]
# <a href="https://colab.research.google.com/github/uladzisly/University/blob/main/tasks/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Введите первый катет')
kat1 = int(input())
print('Введите первый катет')
kat2 = int(input())
print((kat1*kat2)/2)
# Out:
# Введите первый катет
# 3
# Введите первый катет
# 5
# 7.5
